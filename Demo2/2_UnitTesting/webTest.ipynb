# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_csv('HeartDataUnitTest.csv')

# %%
#see a preview of the data
df.head()
# Out:
#    HeartRate      datetime                     Music
# 0         26  1.502285e+09                      Rock
# 1         33  1.502284e+09                    Reggae
# 2         25  1.502284e+09            Easy Listening
# 3         33  1.502283e+09               Latin Music
# 4         40  1.502282e+09  Asian Pop (J-Pop, K-pop)

# %%
# another way of quickly grabbing the information of this set of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 3 columns):
# HeartRate    145 non-null int64
# datetime     145 non-null float64
# Music        145 non-null object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.5+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.plot(x='datetime', y='HeartRate', kind='line') 
plt.show()
plt.savefig('webtest.png')
